# %%
import instascrape
from bs4 import BeautifulSoup
from selenium import webdriver
import re
from webdriver_manager.chrome import ChromeDriverManager
import urllib.parse
from datastructures import Location, Site
from dataclasses_serialization.json import JSONSerializer
import time
import json

driver = webdriver.Chrome(ChromeDriverManager().install())
base_url = "https://www.instagram.com"
driver.get(base_url)  # Navigate to Instagram website

# "Login" to Instagram
cookies = json.loads(open("cookies.json", "r").read())
for cookie in cookies:
    cookie.pop("sameSite")
    driver.add_cookie(cookie)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [/home/matas/.wdm/drivers/chromedriver/linux64/90.0.4430.24/chromedriver] found in cache

# %%
driver.get("https://www.instagram.com")

# %% [markdown]
# # 1. Get a list of all Locations that Instagram supports

# %%
driver.get(urllib.parse.urljoin(base_url, "/explore/locations/US/united-states/"))
soup = BeautifulSoup(driver.page_source)

data = {}

next_page = not None

while next_page is not None:
    next_page = soup.find("a", href=re.compile("\?page="))

    links = soup.find_all("a", href=re.compile("/explore/locations/"))
    for link in links:
        if link.text == "See More":
            continue
        data[link.text] = Location(link.text, link["href"], [])

    if next_page is None:
        break

    print("Getting the next page:", next_page["href"])
    driver.get(urllib.parse.urljoin(base_url, next_page["href"]))
    soup = BeautifulSoup(driver.page_source)
    time.sleep(2)

# Remove last link to more locations
del data["Locations"]
# Out:
# Getting the next page: /explore/locations/US/united-states/?page=2
# Getting the next page: /explore/locations/US/united-states/?page=3
# Getting the next page: /explore/locations/US/united-states/?page=4
# Getting the next page: /explore/locations/US/united-states/?page=5
# Getting the next page: /explore/locations/US/united-states/?page=6
# Getting the next page: /explore/locations/US/united-states/?page=7
# Getting the next page: /explore/locations/US/united-states/?page=8
# Getting the next page: /explore/locations/US/united-states/?page=9
# Getting the next page: /explore/locations/US/united-states/?page=10
# Getting the next page: /explore/locations/US/united-states/?page=11

# %% [markdown]
# # Get the Sites from each Location

# %%
def scrape_location(key: str) -> None:
    location = data[key]
    print(location.name)

    driver.get(urllib.parse.urljoin(base_url, location.link))
    soup = BeautifulSoup(driver.page_source)

    next_page = not None

    while next_page is not None:
        next_page = soup.find("a", href=re.compile("\?page="))

        links = soup.find_all("a", href=re.compile("/explore/locations/[0-9]*/"))
        for i, link in enumerate(links):
            if i % 4 == 0:
                print("Site:", i)
                
            if link.text == "See More":
                continue

            temp = instascrape.Location(urllib.parse.urljoin(base_url, link["href"]))
            try: 
                temp.scrape()
            except Exception as e:
                print("Failed to scrape", link["href"], e)
                continue

            site = Site(link.text, link["href"], temp.amount_of_posts, temp.longitude, temp.latitude)
            if site not in location.sites:
                location.sites.append(site)
            time.sleep(0.1)
            
        if next_page is None:
            break

        print("Getting the next page:", next_page["href"])
        driver.get(urllib.parse.urljoin(base_url, next_page["href"]))
        soup = BeautifulSoup(driver.page_source)
        time.sleep(2)

    serialize_instagram_data(data, f"checkpoint_{location.name}.json")

# %%
# for city in ["New York", "Chicago", "Los Angeles", "Houston", "Boston", "Denver", "Orlando"]:
for city in ["Chicago"]:
    scrape_location(city)
# Out:
# Chicago
# Site: 0
# /home/matas/anaconda3/lib/python3.8/site-packages/instascrape/core/_static_scraper.py:134: MissingCookiesWarning: Request header does not contain cookies! It's recommended you pass at least a valid sessionid otherwise Instagram will likely redirect you to their login page.
#   warnings.warn(
# Site: 4
# Site: 8
# Site: 12
# Site: 16
# Site: 20
# Site: 24
# Site: 28
# Site: 32
# Site: 36
# Site: 40
# Site: 44
# Site: 48
# Site: 52
# Failed to scrape /explore/locations/280362/lou-malnatis/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 56
# Site: 60
# Site: 64
# Failed to scrape /explore/locations/31665/chicago-theatre/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 68
# Site: 72
# Failed to scrape /explore/locations/650788757/dylans-candy-bar-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 76
# Site: 80
# Site: 84
# Site: 88
# Site: 92
# Failed to scrape /explore/locations/433887/rockit-bar-grill/ None is not a valid Instagram page. Please provide a valid argument.
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=2
# Site: 0
# Site: 4
# Failed to scrape /explore/locations/234338124/kimpton-hotel-palomar-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 8
# Site: 12
# Failed to scrape /explore/locations/457425/mercadito-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Failed to scrape /explore/locations/223675892/downtown-on-the-chicago-river/ list index out of range
# Site: 16
# Site: 20
# Site: 24
# Site: 28
# Site: 32
# Site: 36
# Site: 40
# Site: 44
# Failed to scrape /explore/locations/9128915/nellcote/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 48
# Site: 52
# Site: 56
# Site: 60
# Site: 64
# Site: 68
# Failed to scrape /explore/locations/215596451/ruths-chris-steak-house/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 72
# Site: 76
# Failed to scrape /explore/locations/2781161/bridge-house-tavern/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 80
# Site: 84
# Failed to scrape /explore/locations/111357470/willis-tower-skydeck/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 88
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=3
# Site: 0
# Failed to scrape /explore/locations/6615048/slurping-turtle/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 4
# Failed to scrape /explore/locations/999152180162072/bad-hunter/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 8
# Site: 12
# Site: 16
# Failed to scrape /explore/locations/1324075/paris-club-bistro-bar/ None is not a valid Instagram page. Please provide a valid argument.
# Failed to scrape /explore/locations/26725900/intelligentsia-coffee/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 20
# Site: 24
# Site: 28
# Site: 32
# Site: 36
# Failed to scrape /explore/locations/111044/sable-kitchen-bar/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 40
# Failed to scrape /explore/locations/71761266/american-junkie-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 44
# Failed to scrape /explore/locations/16130772/glazed-and-infused-doughnuts/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 48
# Site: 52
# Site: 56
# Site: 60
# Site: 64
# Site: 68
# Site: 72
# Site: 76
# Site: 80
# Site: 84
# Site: 88
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=4
# Site: 0
# Site: 4
# Site: 8
# Site: 12
# Site: 16
# Site: 20
# Site: 24
# Site: 28
# Site: 32
# Site: 36
# Site: 40
# Site: 44
# Site: 48
# Site: 52
# Site: 56
# Site: 60
# Site: 64
# Failed to scrape /explore/locations/986954860/facebook-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 68
# Site: 72
# Site: 76
# Failed to scrape /explore/locations/1925121714417406/blind-barber/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 80
# Site: 84
# Site: 88
# Failed to scrape /explore/locations/174528919581143/beacon-tavern/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=5
# Site: 0
# Failed to scrape /explore/locations/619170649/chicago-river-walk/ None is not a valid Instagram page. Please provide a valid argument.
# Failed to scrape /explore/locations/2109130346029086/ballast-point-chicago/ list index out of range
# Site: 4
# Failed to scrape /explore/locations/8610970/bar-louie/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 8
# Site: 12
# Failed to scrape /explore/locations/6566426/grange-hall/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 16
# Site: 20
# Site: 24
# Site: 28
# Site: 32
# Failed to scrape /explore/locations/771899698/fox-bar-at-soho-house-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 36
# Failed to scrape /explore/locations/283099/bin-36/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 40
# Failed to scrape /explore/locations/190656569/pearl-brasserie/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 44
# Site: 48
# Failed to scrape /explore/locations/806713223013237/barton-g-the-restaurant-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 52
# Failed to scrape /explore/locations/359770265/chicken-farm-shop-at-soho-house-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 56
# Site: 60
# Site: 64
# Site: 68
# Site: 72
# Site: 76
# Site: 80
# Site: 84
# Failed to scrape /explore/locations/138071588/blackfinn-ameripub-river-north/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 88
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=6
# Site: 0
# Failed to scrape /explore/locations/376387204/salero/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 4
# Site: 8
# Site: 12
# Site: 16
# Site: 20
# Site: 24
# Failed to scrape /explore/locations/524874987939943/dicks-last-resort/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 28
# Site: 32
# Site: 36
# Site: 40
# Site: 44
# Site: 48
# Site: 52
# Failed to scrape /explore/locations/354488814/mercer-113/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 56
# Site: 60
# Failed to scrape /explore/locations/81555637/the-black-womens-expo/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 64
# Site: 68
# Failed to scrape /explore/locations/755917738/expat/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 72
# Failed to scrape /explore/locations/33757938/embeya/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 76
# Site: 80
# Site: 84
# Site: 88
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=7
# Site: 0
# Site: 4
# Failed to scrape /explore/locations/1841865/cemitas-puebla/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 8
# Site: 12
# Site: 16
# Site: 20
# Site: 24
# Failed to scrape /explore/locations/1025345160/parlor-pizza-bar/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 28
# Site: 32
# Failed to scrape /explore/locations/557271147814190/parlor-pizza-bar-west-loop/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 36
# Failed to scrape /explore/locations/248602585/lakefront-trail-at-belmont-harbor-roscoe/ list index out of range
# Site: 40
# Site: 44
# Site: 48
# Site: 52
# Site: 56
# Site: 60
# Site: 64
# Site: 68
# Site: 72
# Site: 76
# Site: 80
# Site: 84
# Site: 88
# Site: 92
# Failed to scrape /explore/locations/543578186/the-brass-monkey/ None is not a valid Instagram page. Please provide a valid argument.
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=8
# Site: 0
# Site: 4
# Site: 8
# Site: 12
# Site: 16
# Failed to scrape /explore/locations/578721655644938/mamas-boy-peasant-italian/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 20
# Site: 24
# Site: 28
# Site: 32
# Site: 36
# Failed to scrape /explore/locations/678280893/parlor-pizza-bar/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 40
# Failed to scrape /explore/locations/216729804/chick-fil-a-state-and-lake-in-line/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 44
# Failed to scrape /explore/locations/499530658/left-bank-at-k-station/ Instagram is redirecting you to the login page instead of the page you are trying to scrape. This could be occuring because you made too many requests too quickly or are not logged into Instagram on your machine. Try passing a valid session ID to the scrape method as a cookie to bypass the login requirement
# Site: 48
# Failed to scrape /explore/locations/258813462/sub-51/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 52
# Site: 56
# Site: 60
# Site: 64
# Failed to scrape /explore/locations/206320/block-37/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 68
# Site: 72
# Site: 76
# Site: 80
# Failed to scrape /explore/locations/428148846/chicago-loop/ Instagram is redirecting you to the login page instead of the page you are trying to scrape. This could be occuring because you made too many requests too quickly or are not logged into Instagram on your machine. Try passing a valid session ID to the scrape method as a cookie to bypass the login requirement
# Site: 84
# Failed to scrape /explore/locations/19877207/fitpro-west/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 88
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=9
# Site: 0
# Site: 4
# Failed to scrape /explore/locations/1033625/south-water-kitchen/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 8
# Failed to scrape /explore/locations/349186701/the-lunatic-the-lover-the-poet/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 12
# Site: 16
# Failed to scrape /explore/locations/313451568/space-by-doejo/ None is not a valid Instagram page. Please provide a valid argument.
# Failed to scrape /explore/locations/216998757/washington-wells/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 20
# Site: 24
# Site: 28
# Failed to scrape /explore/locations/1067163636691012/tiny-hatt/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 32
# Site: 36
# Failed to scrape /explore/locations/351207164/sullivans-steakhouse/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 40
# Site: 44
# Site: 48
# Failed to scrape /explore/locations/513088307/ohmculture/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 52
# Site: 56
# Site: 60
# Site: 64
# Site: 68
# Site: 72
# Site: 76
# Site: 80
# Site: 84
# Site: 88
# Failed to scrape /explore/locations/1019114253/morningstar-inc/ list index out of range
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=10
# Site: 0
# Site: 4
# Site: 8
# Site: 12
# Failed to scrape /explore/locations/243995685/willis-tower-united-airlines-world-headquarters/ list index out of range
# Site: 16
# Failed to scrape /explore/locations/1135676/adler-university-chicago-campus/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 20
# Failed to scrape /explore/locations/1641082/tanoshii-andersonville/ None is not a valid Instagram page. Please provide a valid argument.
# Failed to scrape /explore/locations/285122183/mas/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 24
# Site: 28
# Site: 32
# Site: 36
# Failed to scrape /explore/locations/7632994/chicago-sun-times/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 40
# Site: 44
# Site: 48
# Site: 52
# Failed to scrape /explore/locations/948826007/black-iron-tavern/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 56
# Site: 60
# Failed to scrape /explore/locations/260074814/assumption-catholic-church-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 64
# Site: 68
# Site: 72
# Site: 76
# Site: 80
# Site: 84
# Failed to scrape /explore/locations/2633678/angels-and-kings-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 88
# Site: 92
# Getting the next page: /explore/locations/c2438177/chicago-united-states/?page=11
# Site: 0
# Site: 4
# Site: 8
# Failed to scrape /explore/locations/1029720320/river-plaza-chicago/ None is not a valid Instagram page. Please provide a valid argument.
# Site: 12
# Site: 16
# Site: 20
# Site: 24
# Site: 28
# Site: 32
# Site: 36

# %%
serialize_instagram_data(data, "chicago.json")

# %% [markdown]
# ## Serialize / Deserialize the data

# %%
def serialize_instagram_data(data: dict, path: str) -> None:
    with open(path, "w") as file:
        json.dump(JSONSerializer.serialize(data), file)

def deserialize_instagram_data(path: str) -> dict:
    data = json.loads(open(path, "r").read())
    for key, val in data.items():
        data[key] = JSONSerializer.deserialize(Location, data[key])
    return data

# %%
data = deserialize_instagram_data("chicago.json")

# %% [markdown]
# # Count total sites

# %%
print("We scraped", len(data["Chicago"].sites), "sites")
# Out:
# We scraped 924 sites

# %% [markdown]
# # Count total posts in Chicago

# %%
total_posts = 0
for site in data["Chicago"].sites:
    total_posts += site.total_posts
print("There are", f"{total_posts:,}", "location-tagged Instagram posts in Chicago.")
# Out:
# There are 31,525,527 location-tagged Instagram posts in Chicago.

# %% [markdown]
# # Convert to CSV for ArcGIS Feature Class

# %%
with open("data.csv", "w") as file:
    file.write("name,link,total_posts,lon,lat\n")
    for site in data["Chicago"].sites:
        file.write(f'"{site.name}",{site.link},{site.total_posts},{site.lon},{site.lat}\n')

# %% [markdown]
# # Quick Visualization

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.tile_providers import CARTODBPOSITRON, get_provider, OSM, WIKIMEDIA
from bokeh.models import HoverTool, ColumnDataSource
from pyproj import Proj, transform, Transformer

transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)

# %%
# Prepare data for bokeh
x_coords = []
y_coords = []
names = []
posts = []

for site in data["Chicago"].sites:
    if site.lon == 0 and site.lat == 0:  # Skip the sites with no coordinates
        continue

    x, y = transformer.transform(site.lon, site.lat)
    x_coords.append(x)
    y_coords.append(y)
    names.append(site.name)
    posts.append(site.total_posts)

source = ColumnDataSource(data=dict(x=x_coords, y=y_coords, name=names, total_posts=posts))
hover = HoverTool(tooltips=[
    ("(x,y)", "(@x, @y)"),
    ("Name", "@name"),
    ("Total Posts", "@total_posts"),
])

output_notebook()  # Specify that we will be viewing in a Notebook.

tile_provider = get_provider(WIKIMEDIA)  # Set the basemap tile provider
p = figure(x_range=(-9780000, -9745000), y_range=(5130000, 5160000), x_axis_type="mercator", y_axis_type="mercator", plot_height=1000, plot_width=1000)
p.add_tools(hover)
p.add_tile(tile_provider)

p.circle("x", "y", source=source, size=10, color="navy", alpha=0.5)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1956">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="99d1c398-29a6-4c7a-a10a-8ae8ad9be0f2" data-root-id="1958"></div>

# %% [markdown]
# # Change the circle size by the amount of posts

# %%
# Prepare data for bokeh
x_coords = []
y_coords = []
names = []
posts = []
circle_sizes = []  # Scale the circle size by the amount of posts

for site in data["Chicago"].sites:

    if site.lon == 0 and site.lat == 0:  # Skip the sites with no coordinates
        continue

    x, y = transformer.transform(site.lon, site.lat)
    x_coords.append(x)
    y_coords.append(y)
    names.append(site.name)
    posts.append(site.total_posts)
    circle_sizes.append(site.total_posts / 10000)

source = ColumnDataSource(data=dict(x=x_coords, y=y_coords, name=names, total_posts=posts, circle_sizes=circle_sizes))
hover = HoverTool(tooltips=[
    ("(x,y)", "(@x, @y)"),
    ("Name", "@name"),
    ("Total Posts", "@total_posts"),
])

output_notebook()  # Specify that we will be viewing in a Notebook.

tile_provider = get_provider(WIKIMEDIA)  # Set the basemap tile provider
p = figure(x_range=(-9780000, -9745000), y_range=(5130000, 5160000), x_axis_type="mercator", y_axis_type="mercator", plot_height=1000, plot_width=1000)
p.add_tools(hover)
p.add_tile(tile_provider)

p.circle("x", "y", source=source, size="circle_sizes", color="navy", alpha=0.5)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2115">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a7843ba3-2dff-407a-a350-4b09e5e95e4f" data-root-id="2117"></div>

# %% [markdown]
# # Remove "Chicago, Illinois" from the plot

# %%
# Prepare data for bokeh
x_coords = []
y_coords = []
names = []
posts = []
circle_sizes = []  # Scale the circle size by the amount of posts


transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)

for site in data["Chicago"].sites:

    if site.lon == 0 and site.lat == 0 or site.name == "Chicago, Illinois":  # Skip the sites with no coordinates
        continue

    x, y = transformer.transform(site.lon, site.lat)
    x_coords.append(x)
    y_coords.append(y)
    names.append(site.name)
    posts.append(site.total_posts)
    circle_sizes.append(site.total_posts / 2000)

source = ColumnDataSource(data=dict(x=x_coords, y=y_coords, name=names, total_posts=posts, circle_sizes=circle_sizes))
hover = HoverTool(tooltips=[
    ("(x,y)", "(@x, @y)"),
    ("Name", "@name"),
    ("Total Posts", "@total_posts"),
])

output_notebook()  # Specify that we will be viewing in a Notebook.

tile_provider = get_provider(WIKIMEDIA)  # Set the basemap tile provider
p = figure(x_range=(-9780000, -9745000), y_range=(5130000, 5160000), x_axis_type="mercator", y_axis_type="mercator", plot_height=1000, plot_width=1000)
p.add_tools(hover)
p.add_tile(tile_provider)

p.circle("x", "y", source=source, size="circle_sizes", color="navy", alpha=0.5)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2283">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f2f45e49-9527-4cd3-bcd7-9b6a59bf525e" data-root-id="2285"></div>
